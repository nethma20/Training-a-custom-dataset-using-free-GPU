# %%
# !git clone https://github.com/AlexeyAB/darknet

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# [Errno 20] Not a directory: 'darknet'
# /darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# 'Colab Notebooks'  'My Drive'   numbers

# %%
# !cp /mydrive/numbers/num.zip ../

# %%
# !unzip ../num.zip -d data/
# Out:
# Archive:  ../num.zip
#   inflating: data/custom_data/1.png
#   inflating: data/custom_data/1.txt
#   inflating: data/custom_data/10.png
#   inflating: data/custom_data/10.txt
#   inflating: data/custom_data/100.png
#   inflating: data/custom_data/100.txt
#   inflating: data/custom_data/101.png
#   inflating: data/custom_data/101.txt
#   inflating: data/custom_data/102.png
#   inflating: data/custom_data/102.txt
#   inflating: data/custom_data/103.png
#   inflating: data/custom_data/103.txt
#   inflating: data/custom_data/104.png
#   inflating: data/custom_data/104.txt
#   inflating: data/custom_data/105.png
#   inflating: data/custom_data/105.txt
#   inflating: data/custom_data/106.png
#   inflating: data/custom_data/106.txt
#   inflating: data/custom_data/107.png
#  extracting: data/custom_data/107.txt
#   inflating: data/custom_data/108.png
#   inflating: data/custom_data/108.txt
#   inflating: data/custom_data/109.png
#  extracting: data/custom_data/109.txt
# ...

# %%
# !cp /mydrive/numbers/yolov3-custom.cfg ./cfg

# %%
# !cp darknet/cfg/yolov3.cfg /mydrive/numbers/yolov3_custom2.cfg

# %%
# !cp /mydrive/numbers/yolov3-custom.cfg ./darknet/cfg

# %%
# !cp /mydrive/numbers/num.names ./data
# !cp /mydrive/numbers/num.data ./data

# %%
# !cp /mydrive/numbers/generate_train.py ./

# %%
# !python generate_train.py

# %%
# !ls data/
# Out:
# custom_data  num.data  num.names  train.txt

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2022-02-14 17:43:44--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  20.2MB/s    in 8.4s
#
# 2022-02-14 17:43:53 (18.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet/darknet detector train data/num.data darknet/cfg/yolov3-custom.cfg darknet53.conv.74 -dont_show
# Out:
# /bin/bash: ./darknet/darknet: Not a directory

# %%
# !./darknet detector train data/num.data darknet/cfg/yolov3-custom.cfg /mydrive/numbers/backup/yolov3-custom_last.weights -dont_show
# Out:
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 38 : build time: Feb 14 2022 - 17:32:00
#
#  CUDA Error: no CUDA-capable device is detected
# Darknet error location: ./src/dark_cuda.c, check_error, line #69
# CUDA Error: no CUDA-capable device is detected: Bad file descriptor

# %%
# %cd darknet/cfg
# !sed -i 's/batch=64/batch=1' yolov3-custom.cfg
# !sed -i 's/subdivisions=16/subdivisions=1' yolov3-custom.cfg
# %cd ..
# Out:
# /darknet/cfg
# sed: -e expression #1, char 18: unterminated `s' command
# sed: -e expression #1, char 32: unterminated `s' command
# /darknet

# %%
# !./darknet detector test data/num.data darknet/cfg/yolov3-custom.cfg /mydrive/numbers/backup/yolov3-custom_last.weights /mydrive/images/download.jfif -thresh 0.3
imshow ('prediction.jpg')
# Out:
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 38 : build time: Feb 14 2022 - 17:32:00
#
#  CUDA Error: no CUDA-capable device is detected
# Darknet error location: ./src/dark_cuda.c, check_error, line #69
# CUDA Error: no CUDA-capable device is detected: Bad file descriptor
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-9c77ae7454c4> in <module>()
#       1 get_ipython().system('./darknet detector test data/num.data darknet/cfg/yolov3-custom.cfg /mydrive/numbers/backup/yolov3-custom_last.weights /mydrive/images/download.jfif -thresh 0.3')
# ----> 2 imshow ('prediction.jpg')
#
# NameError: name 'imshow' is not defined
